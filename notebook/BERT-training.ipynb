# %% [markdown]
# ## BERT Training
#
# - modeling.py
# - optimization.py
# - tokenization.py
# - run_squad.py
# - run_classifier.py
#
# `python run_squad.py \
#   --vocab_file=$BERT_BASE_DIR/vocab.txt \
#   --bert_config_file=$BERT_BASE_DIR/bert_config.json \
#   --init_checkpoint=$BERT_BASE_DIR/bert_model.ckpt \
#   --do_train=True \
#   --train_file=$SQUAD_DIR/train-v1.1.json \
#   --do_predict=True \
#   --predict_file=$SQUAD_DIR/dev-v1.1.json \
#   --train_batch_size=12 \
#   --learning_rate=3e-5 \
#   --num_train_epochs=2.0 \
#   --max_seq_length=384 \
#   --doc_stride=128 \
#   --output_dir=/tmp/squad_base/`
#
#
# `python run_classifier.py \
#   --task_name=MRPC \
#   --do_train=true \
#   --do_eval=true \
#   --data_dir=$GLUE_DIR/MRPC \
#   --vocab_file=$BERT_BASE_DIR/vocab.txt \
#   --bert_config_file=$BERT_BASE_DIR/bert_config.json \
#   --init_checkpoint=$BERT_BASE_DIR/bert_model.ckpt \
#   --max_seq_length=128 \
#   --train_batch_size=32 \
#   --learning_rate=2e-5 \
#   --num_train_epochs=3.0 \
#   --output_dir=/tmp/mrpc_output/`

# %%
import urllib.request
from google.colab import drive

drive.mount('/content/gdrive')

SAVE_DIR = '/content/gdrive/My Drive/ai-summit/'
def download(url, savedir=SAVE_DIR):
  file_name = url.split('/')[-1]
  download_file = savedir + file_name
  urllib.request.urlretrieve(url, download_file)

download('https://raw.githubusercontent.com/google-research/bert/master/modeling.py')
download('https://raw.githubusercontent.com/google-research/bert/master/optimization.py')
download('https://raw.githubusercontent.com/google-research/bert/master/tokenization.py')
download('https://raw.githubusercontent.com/google-research/bert/master/run_squad.py')
download('https://raw.githubusercontent.com/google-research/bert/master/run_classifier.py')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !ls /content/gdrive/My\ Drive/ai-summit/
# Out:
#  BERT-training.ipynb   model	     optimization.py	 run_squad.py
# '환경 설정.ipynb'      modeling.py   run_classifier.py	 tokenization.py

# %% [markdown]
# ### merge train, dev files

# %%
import glob
import json
from collections import defaultdict

def jsonmerge(dir, output, pattern='*.json'):
  files = glob.glob(dir + pattern)
  merged = defaultdict(list)
  version = ''
  for f in files:
    print(f)
    with open(f, 'r', encoding='utf-8') as f:
      js = json.load(f)
      version = js['version']
      data = js['data']
      merged['data'].append(data)

  merged['version'] = version

  with open(output, 'w') as f:
    json.dump(merged, f)

    

jsonmerge(SAVE_DIR + 'model/train/', SAVE_DIR + 'train.json')
jsonmerge(SAVE_DIR + 'model/dev/', SAVE_DIR + 'dev.json')

# !ls /content/gdrive/My\ Drive/ai-summit/
# Out:
# /content/gdrive/My Drive/ai-summit/model/train/korquad2.1_train_00.json
# /content/gdrive/My Drive/ai-summit/model/train/korquad2.1_train_01.json
# /content/gdrive/My Drive/ai-summit/model/train/korquad2.1_train_02.json
# /content/gdrive/My Drive/ai-summit/model/train/korquad2.1_train_03.json
# /content/gdrive/My Drive/ai-summit/model/train/korquad2.1_train_04.json
# /content/gdrive/My Drive/ai-summit/model/train/korquad2.1_train_05.json
# /content/gdrive/My Drive/ai-summit/model/train/korquad2.1_train_06.json
# /content/gdrive/My Drive/ai-summit/model/train/korquad2.1_train_07.json
# /content/gdrive/My Drive/ai-summit/model/train/korquad2.1_train_08.json
# /content/gdrive/My Drive/ai-summit/model/train/korquad2.1_train_09.json
# /content/gdrive/My Drive/ai-summit/model/train/korquad2.1_train_10.json
# /content/gdrive/My Drive/ai-summit/model/train/korquad2.1_train_11.json
# /content/gdrive/My Drive/ai-summit/model/train/korquad2.1_train_12.json
# /content/gdrive/My Drive/ai-summit/model/train/korquad2.1_train_13.json
# /content/gdrive/My Drive/ai-summit/model/train/korquad2.1_train_14.json
# /content/gdrive/My Drive/ai-summit/model/train/korquad2.1_train_15.json
# /content/gdrive/My Drive/ai-summit/model/train/korquad2.1_train_16.json
# /content/gdrive/My Drive/ai-summit/model/train/korquad2.1_train_17.json
# /content/gdrive/My Drive/ai-summit/model/train/korquad2.1_train_18.json
# /content/gdrive/My Drive/ai-summit/model/train/korquad2.1_train_19.json
# /content/gdrive/My Drive/ai-summit/model/train/korquad2.1_train_20.json
# /content/gdrive/My Drive/ai-summit/model/train/korquad2.1_train_21.json
# /content/gdrive/My Drive/ai-summit/model/train/korquad2.1_train_22.json
# /content/gdrive/My Drive/ai-summit/model/train/korquad2.1_train_23.json
# /content/gdrive/My Drive/ai-summit/model/train/korquad2.1_train_24.json
# /content/gdrive/My Drive/ai-summit/model/train/korquad2.1_train_25.json
# /content/gdrive/My Drive/ai-summit/model/train/korquad2.1_train_26.json
# /content/gdrive/My Drive/ai-summit/model/train/korquad2.1_train_27.json
# /content/gdrive/My Drive/ai-summit/model/train/korquad2.1_train_28.json
# /content/gdrive/My Drive/ai-summit/model/train/korquad2.1_train_29.json
# /content/gdrive/My Drive/ai-summit/model/train/korquad2.1_train_30.json
# /content/gdrive/My Drive/ai-summit/model/train/korquad2.1_train_31.json
# /content/gdrive/My Drive/ai-summit/model/train/korquad2.1_train_32.json
# /content/gdrive/My Drive/ai-summit/model/train/korquad2.1_train_33.json
# /content/gdrive/My Drive/ai-summit/model/train/korquad2.1_train_34.json
# /content/gdrive/My Drive/ai-summit/model/train/korquad2.1_train_35.json
# /content/gdrive/My Drive/ai-summit/model/train/korquad2.1_train_36.json
# /content/gdrive/My Drive/ai-summit/model/train/korquad2.1_train_37.json
# /content/gdrive/My Drive/ai-summit/model/train/korquad2.1_train_38.json
# /content/gdrive/My Drive/ai-summit/model/dev/korquad2.1_dev_00.json
# /content/gdrive/My Drive/ai-summit/model/dev/korquad2.1_dev_01.json
# /content/gdrive/My Drive/ai-summit/model/dev/korquad2.1_dev_02.json
# /content/gdrive/My Drive/ai-summit/model/dev/korquad2.1_dev_03.json
# /content/gdrive/My Drive/ai-summit/model/dev/korquad2.1_dev_04.json
#  BERT-training.ipynb   model		 run_classifier.py   train.json
#  dev.json	       modeling.py	 run_squad.py
# '환경 설정.ipynb'      optimization.py	 tokenization.py

# %%
## 기본 메모리 부족
import json
json_file = open('/content/gdrive/My Drive/ai-summit/train.json', encoding='utf-8')
json_data = json.load(json_file)

print(len(json_data['data']))

# %%
## SQuAD data

download('https://rajpurkar.github.io/SQuAD-explorer/dataset/train-v2.0.json', '/content/gdrive/My Drive/ai-summit/')

import json

def showJson(f, showcnt=0):
  json_file = open(f)
  json_data = json.load(json_file)
  cnt = len(json_data['data'])
  if showcnt >= cnt:
    showcnt = cnt
  print(json.dumps(json_data['data'][showcnt], indent=2))

# %%
showJson('/content/gdrive/My Drive/ai-summit/train-v2.0.json', 20)
# Out:
# {
#   "title": "Wayback_Machine",
#   "paragraphs": [
#     {
#       "qas": [
#         {
#           "question": "Where does the information stored on the Wayback Machine come from?",
#           "id": "56ddb46c9a695914005b958e",
#           "answers": [
#             {
#               "text": "World Wide Web",
#               "answer_start": 48
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "question": "Which company made the Wayback Machine?",
#           "id": "56ddb46c9a695914005b958f",
#           "answers": [
#             {
#               "text": "Internet Archive",
#               "answer_start": 116
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "question": "Where is Internet Archive headquartered?",
#           "id": "56ddb46c9a695914005b9590",
#           "answers": [
#             {
#               "text": "San Francisco",
#               "answer_start": 169
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "question": "What individuals founded Internet Archive?",
#           "id": "56ddb46c9a695914005b9591",
#           "answers": [
#             {
#               "text": "Brewster Kahle and Bruce Gilliat",
#               "answer_start": 228
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "question": "What is the term used by Internet Archive to describe the Wayback Machine?",
#           "id": "56ddb46c9a695914005b9592",
#           "answers": [
#             {
#               "text": "three dimensional index",
#               "answer_start": 418
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "World Wide Web",
#               "answer_start": 48
#             }
#           ],
#           "question": "Where does the information stored on the Internet Archive come from?",
#           "id": "5a6afdb2a9e0c9001a4e9e38",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "Internet Archive",
#               "answer_start": 116
#             }
#           ],
#           "question": "Which company made the World Wide Web?",
#           "id": "5a6afdb2a9e0c9001a4e9e39",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "San Francisco",
#               "answer_start": 169
#             }
#           ],
#           "question": "Where is Bruce Gillat headquartered?",
#           "id": "5a6afdb2a9e0c9001a4e9e3a",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "Brewster Kahle and Bruce Gilliat",
#               "answer_start": 228
#             }
#           ],
#           "question": "What individuals founded the World Wide Web?",
#           "id": "5a6afdb2a9e0c9001a4e9e3b",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "three dimensional index",
#               "answer_start": 418
#             }
#           ],
#           "question": "What is the term used by the World Wide Web to describe the Wayback Machine?",
#           "id": "5a6afdb2a9e0c9001a4e9e3c",
#           "answers": [],
#           "is_impossible": true
#         }
#       ],
#       "context": "The Wayback Machine is a digital archive of the World Wide Web and other information on the Internet created by the Internet Archive, a nonprofit organization, based in San Francisco, California, United States. It was set up by Brewster Kahle and Bruce Gilliat, and is maintained with content from Alexa Internet. The service enables users to see archived versions of web pages across time, which the archive calls a \"three dimensional index.\""
#     },
#     {
#       "qas": [
#         {
#           "question": "What operating system is used on Wayback Machine's servers?",
#           "id": "56ddb53b66d3e219004daca3",
#           "answers": [
#             {
#               "text": "Linux",
#               "answer_start": 91
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "question": "When does Wayback Machine save a copy of a website?",
#           "id": "56ddb53b66d3e219004daca4",
#           "answers": [
#             {
#               "text": "if the content has changed",
#               "answer_start": 175
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "question": "What is the ultimate aim of the Wayback Machine?",
#           "id": "56ddb53b66d3e219004daca5",
#           "answers": [
#             {
#               "text": "to archive the entire Internet",
#               "answer_start": 425
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "Linux",
#               "answer_start": 91
#             }
#           ],
#           "question": "What operating system is used on the internet's servers?",
#           "id": "5a6afe8da9e0c9001a4e9e42",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "if the content has changed",
#               "answer_start": 175
#             }
#           ],
#           "question": "When does the internet save a copy of a website?",
#           "id": "5a6afe8da9e0c9001a4e9e43",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "to archive the entire Internet",
#               "answer_start": 425
#             }
#           ],
#           "question": "What is the ultimate aim of the visitors?",
#           "id": "5a6afe8da9e0c9001a4e9e44",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "on the fly",
#               "answer_start": 230
#             }
#           ],
#           "question": "Where can sites be captured by Linux clusters?",
#           "id": "5a6afe8da9e0c9001a4e9e45",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "content that otherwise would be lost whenever a site is changed or closed down",
#               "answer_start": 323
#             }
#           ],
#           "question": "What Linux nodes are hoped to be captured?",
#           "id": "5a6afe8da9e0c9001a4e9e46",
#           "answers": [],
#           "is_impossible": true
#         }
#       ],
#       "context": "Since 1996, they have been archiving cached pages of web sites onto their large cluster of Linux nodes. They revisit sites every few weeks or months and archive a new version if the content has changed. Sites can also be captured on the fly by visitors who are offered a link to do so. The intent is to capture and archive content that otherwise would be lost whenever a site is changed or closed down. Their grand vision is to archive the entire Internet."
#     },
#     {
#       "qas": [
#         {
#           "question": "What TV show served as inspiration for the Wayback Machine's name?",
#           "id": "56ddb92966d3e219004daca9",
#           "answers": [
#             {
#               "text": "The Rocky and Bullwinkle Show",
#               "answer_start": 105
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "question": "Which characters on The Rocky and Bullwinkle Show used a device that allowed them to travel through time?",
#           "id": "56ddb92966d3e219004dacaa",
#           "answers": [
#             {
#               "text": "Mr. Peabody and Sherman",
#               "answer_start": 235
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "question": "What was the machine used by Mr. Peabody and Sherman named?",
#           "id": "56ddb92966d3e219004dacab",
#           "answers": [
#             {
#               "text": "WABAC machine",
#               "answer_start": 301
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "The Rocky and Bullwinkle Show",
#               "answer_start": 105
#             }
#           ],
#           "question": "What TV show served as inspiration for WABAC's name?",
#           "id": "5a6b0007a9e0c9001a4e9e4c",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "Mr. Peabody and Sherman",
#               "answer_start": 235
#             }
#           ],
#           "question": "Which characters on The Rocky and Bullwinkle Show used a device that allowed the to travel through WABAC?",
#           "id": "5a6b0007a9e0c9001a4e9e4d",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "WABAC machine",
#               "answer_start": 301
#             }
#           ],
#           "question": "What was the machine used by Rocky named?",
#           "id": "5a6b0007a9e0c9001a4e9e4e",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "WABAC machine",
#               "answer_start": 301
#             }
#           ],
#           "question": "What was used to alter events in a plot?",
#           "id": "5a6b0007a9e0c9001a4e9e4f",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "Wayback Machine",
#               "answer_start": 9
#             }
#           ],
#           "question": "What was chosen as a droll reference to alter Mr. Peabody?",
#           "id": "5a6b0007a9e0c9001a4e9e50",
#           "answers": [],
#           "is_impossible": true
#         }
#       ],
#       "context": "The name Wayback Machine was chosen as a droll reference to a plot device in an animated cartoon series, The Rocky and Bullwinkle Show. In one of the animated cartoon's component segments, Peabody's Improbable History, lead characters Mr. Peabody and Sherman routinely used a time machine called the \"WABAC machine\" (pronounced way-back) to witness, participate in, and, more often than not, alter famous events in history."
#     },
#     {
#       "qas": [
#         {
#           "question": "When was the program necessary to crawl and archive the web created?",
#           "id": "56ddbae166d3e219004dacaf",
#           "answers": [
#             {
#               "text": "1996",
#               "answer_start": 3
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "question": "What is a term used for programs that automatically visit websites and record the data they find?",
#           "id": "56ddbae166d3e219004dacb0",
#           "answers": [
#             {
#               "text": "crawlers",
#               "answer_start": 260
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "question": "What rule do crawlers abide by when determining which sites to record?",
#           "id": "56ddbae166d3e219004dacb1",
#           "answers": [
#             {
#               "text": "robots exclusion standard",
#               "answer_start": 470
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "question": "What site was created to mitigate issues with incomplete copies of websites?",
#           "id": "56ddbae166d3e219004dacb2",
#           "answers": [
#             {
#               "text": "Archive-It.org",
#               "answer_start": 640
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "1996",
#               "answer_start": 3
#             }
#           ],
#           "question": "When was the program necessary to include all information available on the interet created?",
#           "id": "5a6b01dba9e0c9001a4e9e56",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "crawlers",
#               "answer_start": 260
#             }
#           ],
#           "question": "What is a term used for programs that automatically visit websites and record the board system they find?",
#           "id": "5a6b01dba9e0c9001a4e9e57",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "robots exclusion standard",
#               "answer_start": 470
#             }
#           ],
#           "question": "What rule do web sites abide by when determining sites to record?",
#           "id": "5a6b01dba9e0c9001a4e9e58",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "Archive-It.org",
#               "answer_start": 640
#             }
#           ],
#           "question": "What site was created to mitigate issues with Bruce Gilliat?",
#           "id": "5a6b01dba9e0c9001a4e9e59",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "1996",
#               "answer_start": 3
#             }
#           ],
#           "question": "When did Brewster Kate and Bruce Gilliat develop software to download crawlwers?",
#           "id": "5a6b01dba9e0c9001a4e9e5a",
#           "answers": [],
#           "is_impossible": true
#         }
#       ],
#       "context": "In 1996 Brewster Kahle, with Bruce Gilliat, developed software to crawl and download all publicly accessible World Wide Web pages, the Gopher hierarchy, the Netnews (Usenet) bulletin board system, and downloadable software. The information collected by these \"crawlers\" does not include all the information available on the Internet, since much of the data is restricted by the publisher or stored in databases that are not accessible. These \"crawlers\" also respect the robots exclusion standard for websites whose owners opt for them not to appear in search results or be cached. To overcome inconsistencies in partially cached web sites, Archive-It.org was developed in 2005 by the Internet Archive as a means of allowing institutions and content creators to voluntarily harvest and preserve collections of digital content, and create digital archives."
#     },
#     {
#       "qas": [
#         {
#           "question": "What medium was originally used to keep Internet Archive's data?",
#           "id": "56ddbb4b66d3e219004dacb7",
#           "answers": [
#             {
#               "text": "digital tape",
#               "answer_start": 29
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "question": "Who were sometimes permitted to use the Archive's database?",
#           "id": "56ddbb4b66d3e219004dacb8",
#           "answers": [
#             {
#               "text": "researchers and scientists",
#               "answer_start": 91
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "question": "At what milestone was the archive made public?",
#           "id": "56ddbb4b66d3e219004dacb9",
#           "answers": [
#             {
#               "text": "fifth anniversary",
#               "answer_start": 180
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "question": "Where was the event launching the publicly-available archive held?",
#           "id": "56ddbb4b66d3e219004dacba",
#           "answers": [
#             {
#               "text": "University of California, Berkeley",
#               "answer_start": 261
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "digital tape",
#               "answer_start": 29
#             }
#           ],
#           "question": "What medium was originally used to keep California's data?",
#           "id": "5a6b036ba9e0c9001a4e9e60",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "researchers and scientists",
#               "answer_start": 91
#             }
#           ],
#           "question": "Who were sometimes permitted to attend the Archive's public ceremony?",
#           "id": "5a6b036ba9e0c9001a4e9e61",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "fifth anniversary",
#               "answer_start": 180
#             }
#           ],
#           "question": "At what milestone was the archive made clunky?",
#           "id": "5a6b036ba9e0c9001a4e9e62",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "University of California, Berkeley",
#               "answer_start": 261
#             }
#           ],
#           "question": "Where was the event launching the digital tape held?",
#           "id": "5a6b036ba9e0c9001a4e9e63",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "Kahle",
#               "answer_start": 63
#             }
#           ],
#           "question": "Who allowed researchers and scientists to tap into Berkeley?",
#           "id": "5a6b036ba9e0c9001a4e9e64",
#           "answers": [],
#           "is_impossible": true
#         }
#       ],
#       "context": "Information had been kept on digital tape for five years, with Kahle occasionally allowing researchers and scientists to tap into the clunky database. When the archive reached its fifth anniversary, it was unveiled and opened to the public in a ceremony at the University of California, Berkeley."
#     },
#     {
#       "qas": [
#         {
#           "question": "What are the saved versions of a site called?",
#           "id": "56ddbc0e66d3e219004dacbf",
#           "answers": [
#             {
#               "text": "Snapshots",
#               "answer_start": 0
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "question": "What is the minimum amount of time that elapses before most snapshots are released for viewing?",
#           "id": "56ddbc0e66d3e219004dacc0",
#           "answers": [
#             {
#               "text": "six months",
#               "answer_start": 45
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "question": "What term characterizes the rate at which snapshots are made of websites?",
#           "id": "56ddbc0e66d3e219004dacc1",
#           "answers": [
#             {
#               "text": "variable",
#               "answer_start": 184
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "Snapshots",
#               "answer_start": 0
#             }
#           ],
#           "question": "What are the saved versions of an update called?",
#           "id": "5a6b045ca9e0c9001a4e9e6a",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "six months",
#               "answer_start": 45
#             }
#           ],
#           "question": "What is the minimum amount of time that elapses before most snapshots are released for recording?",
#           "id": "5a6b045ca9e0c9001a4e9e6b",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "variable",
#               "answer_start": 184
#             }
#           ],
#           "question": "What term characterizes the rate at which intervals of websites are made?",
#           "id": "5a6b045ca9e0c9001a4e9e6c",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "twenty-four months",
#               "answer_start": 123
#             }
#           ],
#           "question": "How many months can it take for intervals to become available?",
#           "id": "5a6b045ca9e0c9001a4e9e6d",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "several weeks or years",
#               "answer_start": 277
#             }
#           ],
#           "question": "How long are intervals between cases?",
#           "id": "5a6b045ca9e0c9001a4e9e6e",
#           "answers": [],
#           "is_impossible": true
#         }
#       ],
#       "context": "Snapshots usually become available more than six months after they are archived or, in some cases, even later; it can take twenty-four months or longer.  The frequency of snapshots is variable, so not all tracked web site updates are recorded. Sometimes there are intervals of several weeks or years between snapshots."
#     },
#     {
#       "qas": [
#         {
#           "question": "When did it become a requirement for websites to appear on Open Directory for inclusion in the Archive?",
#           "id": "56ddbc9766d3e219004dacc5",
#           "answers": [
#             {
#               "text": "After August 2008",
#               "answer_start": 0
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "question": "Who stated that sites not on Open Directory were still being saved but would not be released until the Archive was reindexed?",
#           "id": "56ddbc9766d3e219004dacc6",
#           "answers": [
#             {
#               "text": "Jeff Kaplan",
#               "answer_start": 101
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "question": "When did Kaplan make comments about the status of non-Open Directory sites?",
#           "id": "56ddbc9766d3e219004dacc7",
#           "answers": [
#             {
#               "text": "November 2010",
#               "answer_start": 140
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "After August 2008",
#               "answer_start": 0
#             }
#           ],
#           "question": "When did it become a requirement for websites to appear on Open Directory for inclusion in Kaplan?",
#           "id": "5a6b06d9a9e0c9001a4e9e74",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "Jeff Kaplan",
#               "answer_start": 101
#             }
#           ],
#           "question": "Who stated that sites not on Open Directory were still being saved but would not be released until the Kaplan was reindexed?",
#           "id": "5a6b06d9a9e0c9001a4e9e75",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "November 2010",
#               "answer_start": 140
#             }
#           ],
#           "question": "When did Kaplan make comments about the status of Open Directory sites?",
#           "id": "5a6b06d9a9e0c9001a4e9e76",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "in order to be included",
#               "answer_start": 63
#             }
#           ],
#           "question": "Why were sites listed on the Internet Archive after August 2008?",
#           "id": "5a6b06d9a9e0c9001a4e9e77",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "November 2010",
#               "answer_start": 140
#             }
#           ],
#           "question": "When did Kaplan make comments about the Open Directory?",
#           "id": "5a6b06d9a9e0c9001a4e9e78",
#           "answers": [],
#           "is_impossible": true
#         }
#       ],
#       "context": "After August 2008 sites had to be listed on the Open Directory in order to be included. According to Jeff Kaplan of the Internet Archive in November 2010, other sites were still being archived, but more recent captures would become visible only after the next major indexing, an infrequent operation."
#     },
#     {
#       "qas": [
#         {
#           "question": "In 2009, what size did the data saved by Wayback Machine reach?",
#           "id": "56ddbd6d66d3e219004daccb",
#           "answers": [
#             {
#               "text": "three petabytes",
#               "answer_start": 64
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "question": "As of 2003, what was the rate of increase in the amount of data recorded by the Wayback Machine?",
#           "id": "56ddbd6d66d3e219004daccc",
#           "answers": [
#             {
#               "text": "12 terabytes/month",
#               "answer_start": 180
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "question": "Where does Wayback Machine keep its information stored?",
#           "id": "56ddbd6d66d3e219004daccd",
#           "answers": [
#             {
#               "text": "PetaBox rack systems",
#               "answer_start": 222
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "question": "Who makes PetaBox rack systems?",
#           "id": "56ddbd6d66d3e219004dacce",
#           "answers": [
#             {
#               "text": "Capricorn Technologies",
#               "answer_start": 259
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "three petabytes",
#               "answer_start": 64
#             }
#           ],
#           "question": "In 2009, what size did the data saved by rate systems reach?",
#           "id": "5a6b07d7a9e0c9001a4e9e7e",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "12 terabytes/month",
#               "answer_start": 180
#             }
#           ],
#           "question": "As of 2003, what was the rate of increase in the amount of data recorded by rate systems?",
#           "id": "5a6b07d7a9e0c9001a4e9e7f",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "PetaBox rack systems",
#               "answer_start": 222
#             }
#           ],
#           "question": "Where does Wayback Machine keep its technologies stored?",
#           "id": "5a6b07d7a9e0c9001a4e9e80",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "Capricorn Technologies",
#               "answer_start": 259
#             }
#           ],
#           "question": "Who makes rate systems?",
#           "id": "5a6b07d7a9e0c9001a4e9e81",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "data",
#               "answer_start": 204
#             }
#           ],
#           "question": "What is stored on Petabox petabyte systems?",
#           "id": "5a6b07d7a9e0c9001a4e9e82",
#           "answers": [],
#           "is_impossible": true
#         }
#       ],
#       "context": "As of 2009[update], the Wayback Machine contained approximately three petabytes of data and was growing at a rate of 100 terabytes each month; the growth rate reported in 2003 was 12 terabytes/month. The data is stored on PetaBox rack systems manufactured by Capricorn Technologies."
#     },
#     {
#       "qas": [
#         {
#           "question": "When did Internet Archive chance its platform for data storage?",
#           "id": "56ddc1d966d3e219004dacd3",
#           "answers": [
#             {
#               "text": "2009",
#               "answer_start": 3
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "question": "Which platform did Internet Archive adopt in 2009?",
#           "id": "56ddc1d966d3e219004dacd4",
#           "answers": [
#             {
#               "text": "Sun Open Storage",
#               "answer_start": 78
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "question": "Where does Internet archive run a datacenter?",
#           "id": "56ddc1d966d3e219004dacd5",
#           "answers": [
#             {
#               "text": "Sun Microsystems' California campus",
#               "answer_start": 155
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "2009",
#               "answer_start": 3
#             }
#           ],
#           "question": "When did Internet Archive chance its platform for California?",
#           "id": "5a6b0974a9e0c9001a4e9e88",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "Sun Open Storage,",
#               "answer_start": 78
#             }
#           ],
#           "question": "Which campus did Internet Archive adopt 2009?",
#           "id": "5a6b0974a9e0c9001a4e9e89",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "Sun Microsystems' California campus",
#               "answer_start": 155
#             }
#           ],
#           "question": "Where does Internet archive run a sun storage center?",
#           "id": "5a6b0974a9e0c9001a4e9e8a",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "2009",
#               "answer_start": 3
#             }
#           ],
#           "question": "When did the Internet Archive leave California?",
#           "id": "5a6b0974a9e0c9001a4e9e8b",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "California",
#               "answer_start": 173
#             }
#           ],
#           "question": "What state is home to the first data center?",
#           "id": "5a6b0974a9e0c9001a4e9e8c",
#           "answers": [],
#           "is_impossible": true
#         }
#       ],
#       "context": "In 2009, the Internet Archive migrated its customized storage architecture to Sun Open Storage, and hosts a new data center in a Sun Modular Datacenter on Sun Microsystems' California campus."
#     },
#     {
#       "qas": [
#         {
#           "question": "When was an upgrade of the Wayback Machine released for testing?",
#           "id": "56ddc21866d3e219004dacd9",
#           "answers": [
#             {
#               "text": "2011",
#               "answer_start": 3
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "2011",
#               "answer_start": 3
#             }
#           ],
#           "question": "When was an upgrade of the game released for testing?",
#           "id": "5a6b0a37a9e0c9001a4e9e92",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "interface",
#               "answer_start": 72
#             }
#           ],
#           "question": "What did the Wayback Machine keep the same?",
#           "id": "5a6b0a37a9e0c9001a4e9e93",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "Wayback Machine",
#               "answer_start": 39
#             }
#           ],
#           "question": "What was closed for testing?",
#           "id": "5a6b0a37a9e0c9001a4e9e94",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "Wayback Machine",
#               "answer_start": 39
#             }
#           ],
#           "question": "What used the same index of archived content?",
#           "id": "5a6b0a37a9e0c9001a4e9e95",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "2011",
#               "answer_start": 3
#             }
#           ],
#           "question": "When was the Wayback Machine retired?",
#           "id": "5a6b0a37a9e0c9001a4e9e96",
#           "answers": [],
#           "is_impossible": true
#         }
#       ],
#       "context": "In 2011 a new, improved version of the Wayback Machine, with an updated interface and fresher index of archived content, was made available for public testing."
#     },
#     {
#       "qas": [
#         {
#           "question": "When were details of the test version of the updated Wayback Machine released?",
#           "id": "56ddc47666d3e219004dacdd",
#           "answers": [
#             {
#               "text": "March 2011",
#               "answer_start": 3
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "question": "The older version of Wayback Machine did not have much new data past what year?",
#           "id": "56ddc47666d3e219004dacde",
#           "answers": [
#             {
#               "text": "2008",
#               "answer_start": 303
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "question": "The newer version of the Wayback Machine included date up to and including what year?",
#           "id": "56ddc47666d3e219004dacdf",
#           "answers": [
#             {
#               "text": "2010",
#               "answer_start": 169
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "March 2011",
#               "answer_start": 3
#             }
#           ],
#           "question": "When were details of the final version of the released?",
#           "id": "5a6b0e56a9e0c9001a4e9e9c",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "2008",
#               "answer_start": 303
#             }
#           ],
#           "question": "Past what year did the older version of Wayback Machine had  much new data?",
#           "id": "5a6b0e56a9e0c9001a4e9e9d",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "2010",
#               "answer_start": 169
#             }
#           ],
#           "question": "In what year was the oldest version of the Wayback Machine?",
#           "id": "5a6b0e56a9e0c9001a4e9e9e",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "March 2011",
#               "answer_start": 3
#             }
#           ],
#           "question": "When did the Wayback Forum talk about the predecessor to the Wayback Machine?",
#           "id": "5a6b0e56a9e0c9001a4e9e9f",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "classic Wayback Machine",
#               "answer_start": 240
#             }
#           ],
#           "question": "What only has a little bit of material past 2007?",
#           "id": "5a6b0e56a9e0c9001a4e9ea0",
#           "answers": [],
#           "is_impossible": true
#         }
#       ],
#       "context": "In March 2011, it was said on the Wayback Machine forum that \"The Beta of the new Wayback Machine has a more complete and up-to-date index of all crawled materials into 2010, and will continue to be updated regularly. The index driving the classic Wayback Machine only has a little bit of material past 2008, and no further index updates are planned, as it will be phased out this year\"."
#     },
#     {
#       "qas": [
#         {
#           "question": "What was the functionality called that gave users the ability to save a snapshot of a site?",
#           "id": "56ddc4d99a695914005b95bc",
#           "answers": [
#             {
#               "text": "Save a Page",
#               "answer_start": 44
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "question": "When was Save a Page made available?",
#           "id": "56ddc4d99a695914005b95bd",
#           "answers": [
#             {
#               "text": "October 2013",
#               "answer_start": 3
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "Save a Page",
#               "answer_start": 44
#             }
#           ],
#           "question": "What was the functionality called that gave users the ability to save a URL of a site?",
#           "id": "5a6b0f05a9e0c9001a4e9ea6",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "October 2013",
#               "answer_start": 3
#             }
#           ],
#           "question": "When was a URL available?",
#           "id": "5a6b0f05a9e0c9001a4e9ea7",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "Save a Page",
#               "answer_start": 44
#             }
#           ],
#           "question": "What became a threat of theft?",
#           "id": "5a6b0f05a9e0c9001a4e9ea8",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "October 2013",
#               "answer_start": 3
#             }
#           ],
#           "question": "When did the company announce \"Save a Binary\"?",
#           "id": "5a6b0f05a9e0c9001a4e9ea9",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "malicious binaries",
#               "answer_start": 187
#             }
#           ],
#           "question": "What did \"Save a Company\" host?",
#           "id": "5a6b0f05a9e0c9001a4e9eaa",
#           "answers": [],
#           "is_impossible": true
#         }
#       ],
#       "context": "In October 2013, the company announced the \"Save a Page\" feature which allows any Internet user to archive the contents of a URL. This became a threat of abuse by the service for hosting malicious binaries."
#     },
#     {
#       "qas": [
#         {
#           "question": "What 2009 court battle involved the Wayback Machine?",
#           "id": "56ddc5e59a695914005b95c0",
#           "answers": [
#             {
#               "text": "Netbula, LLC v. Chordiant Software Inc.",
#               "answer_start": 16
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "question": "Which company thought that Wayback Machine data was important for its argument?",
#           "id": "56ddc5e59a695914005b95c1",
#           "answers": [
#             {
#               "text": "Chordiant",
#               "answer_start": 32
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "question": "What did Chordiant request that the court deactivate on Netbula's website?",
#           "id": "56ddc5e59a695914005b95c2",
#           "answers": [
#             {
#               "text": "the robots.txt file",
#               "answer_start": 121
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "Netbula, LLC v. Chordiant Software Inc.",
#               "answer_start": 16
#             }
#           ],
#           "question": "What 2009 court battle involved Netbula's robots?",
#           "id": "5a6b1064a9e0c9001a4e9eb0",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "Chordiant",
#               "answer_start": 302
#             }
#           ],
#           "question": "Which company thought that Wayback Machine data was important for robots?",
#           "id": "5a6b1064a9e0c9001a4e9eb1",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "the robots.txt file",
#               "answer_start": 121
#             }
#           ],
#           "question": "What did the Wayback Machine request that the court deactivate on Netbulas website?",
#           "id": "5a6b1064a9e0c9001a4e9eb2",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "pages",
#               "answer_start": 291
#             }
#           ],
#           "question": "What did the Wayback Machine believe would support its case?",
#           "id": "5a6b1064a9e0c9001a4e9eb3",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "Chordiant",
#               "answer_start": 67
#             }
#           ],
#           "question": "Who filed a motion to compel the Wayback Machine to disable the robots.txt file?",
#           "id": "5a6b1064a9e0c9001a4e9eb4",
#           "answers": [],
#           "is_impossible": true
#         }
#       ],
#       "context": "In a 2009 case, Netbula, LLC v. Chordiant Software Inc., defendant Chordiant filed a motion to compel Netbula to disable the robots.txt file on its web site that was causing the Wayback Machine to retroactively remove access to previous versions of pages it had archived from Nebula's site, pages that Chordiant believed would support its case."
#     },
#     {
#       "qas": [
#         {
#           "question": "Who did Netbula believe was the entity that should be responsible for the availability of its snapshots?",
#           "id": "56ddc68966d3e219004dace5",
#           "answers": [
#             {
#               "text": "Internet Archive",
#               "answer_start": 138
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "question": "Which party did Internet Archive side with?",
#           "id": "56ddc68966d3e219004dace6",
#           "answers": [
#             {
#               "text": "Chordiant",
#               "answer_start": 246
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "Internet Archive",
#               "answer_start": 138
#             }
#           ],
#           "question": "Who did Netbula believe was the entity that should be responsible for the availability of its expenses?",
#           "id": "5a6b12d5a9e0c9001a4e9eba",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "Chordiant",
#               "answer_start": 246
#             }
#           ],
#           "question": "Which party did Netbula side with?",
#           "id": "5a6b12d5a9e0c9001a4e9ebb",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "Netbula",
#               "answer_start": 0
#             }
#           ],
#           "question": "Who objected to the motion on the ground that defendants were asking to alter Chordiant's web site?",
#           "id": "5a6b12d5a9e0c9001a4e9ebc",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "considerable burden, expense and disruption to its operations",
#               "answer_start": 351
#             }
#           ],
#           "question": "What would producing web pages have caused Netbula?",
#           "id": "5a6b12d5a9e0c9001a4e9ebd",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "An employee of Internet Archive",
#               "answer_start": 179
#             }
#           ],
#           "question": "Who filed a sworn statement supporting Netubla's motion?",
#           "id": "5a6b12d5a9e0c9001a4e9ebe",
#           "answers": [],
#           "is_impossible": true
#         }
#       ],
#       "context": "Netbula objected to the motion on the ground that defendants were asking to alter Netbula's web site and that they should have subpoenaed Internet Archive for the pages directly. An employee of Internet Archive filed a sworn statement supporting Chordiant's motion, however, stating that it could not produce the web pages by any other means \"without considerable burden, expense and disruption to its operations.\""
#     },
#     {
#       "qas": [
#         {
#           "question": "Which judge presided over the Netbula v. Chordiant case?",
#           "id": "56ddc6e266d3e219004daceb",
#           "answers": [
#             {
#               "text": "Magistrate Judge Howard Lloyd",
#               "answer_start": 0
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "question": "In what jurisdiction was the Netbula v. Chordiant case tried?",
#           "id": "56ddc6e266d3e219004dacec",
#           "answers": [
#             {
#               "text": "Northern District of California, San Jose Division",
#               "answer_start": 37
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "question": "Which party won its argument regarding Netbula's robots.txt file?",
#           "id": "56ddc6e266d3e219004daced",
#           "answers": [
#             {
#               "text": "Chordiant",
#               "answer_start": 200
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "Magistrate Judge Howard Lloyd",
#               "answer_start": 0
#             }
#           ],
#           "question": "Which judge presided over the California v. Chordiant case?",
#           "id": "5a6b1401a9e0c9001a4e9ec4",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "Northern District of California, San Jose",
#               "answer_start": 37
#             }
#           ],
#           "question": "In what jurisdiction was the California v. Chordiant case tried?",
#           "id": "5a6b1401a9e0c9001a4e9ec5",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "Chordiant",
#               "answer_start": 200
#             }
#           ],
#           "question": "Which party won its argument regarding California's robots.txt file?",
#           "id": "5a6b1401a9e0c9001a4e9ec6",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "Magistrate Judge Howard Lloyd",
#               "answer_start": 0
#             }
#           ],
#           "question": "Who rejected California's arguments?",
#           "id": "5a6b1401a9e0c9001a4e9ec7",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "to allow Chordiant to retrieve the archived pages that they sought",
#               "answer_start": 191
#             }
#           ],
#           "question": "Why was California allowed to disable the robots.txt blockage?",
#           "id": "5a6b1401a9e0c9001a4e9ec8",
# ...
#     },
#     {
#       "qas": [
#         {
#           "question": "What kind of protocol is the Robots Exclusion Standard?",
#           "id": "56ddd60966d3e219004dad15",
#           "answers": [
#             {
#               "text": "voluntary",
#               "answer_start": 63
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "question": "What file is utilized to exercise the rights promoted by the Robots Exclusion Standard?",
#           "id": "56ddd60966d3e219004dad16",
#           "answers": [
#             {
#               "text": "Robots.txt",
#               "answer_start": 0
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "question": "If a site prevents Internet Archive from recording it, what file is still saved?",
#           "id": "56ddd60966d3e219004dad17",
#           "answers": [
#             {
#               "text": "Robots.txt",
#               "answer_start": 0
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "voluntary",
#               "answer_start": 63
#             }
#           ],
#           "question": "What kind of protocol is the Internet Archive?",
#           "id": "5a6b2699a9e0c9001a4e9f0a",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "robots.txt",
#               "answer_start": 377
#             }
#           ],
#           "question": "What file is utilized to exercise the rights promoted by the Internet Archive?",
#           "id": "5a6b2699a9e0c9001a4e9f0b",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "robots.txt",
#               "answer_start": 377
#             }
#           ],
#           "question": "If a site prevents Internet Archive from recording it, what file is rendered unavailable?",
#           "id": "5a6b2699a9e0c9001a4e9f0c",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "Robots Exclusion Standard",
#               "answer_start": 34
#             }
#           ],
#           "question": "What does the Healthcare Advocates respect?",
#           "id": "5a6b2699a9e0c9001a4e9f0d",
#           "answers": [],
#           "is_impossible": true
#         }
#       ],
#       "context": "Robots.txt is used as part of the Robots Exclusion Standard, a voluntary protocol the Internet Archive respects that disallows bots from indexing certain pages delineated by its creator as off-limits. As a result, the Internet Archive has rendered unavailable a number of web sites that now are inaccessible through the Wayback Machine. Currently, the Internet Archive applies robots.txt rules retroactively; if a site blocks the Internet Archive, such as Healthcare Advocates, any previously archived pages from the domain are rendered unavailable as well. In cases of blocked sites, only the robots.txt file is archived."
#     },
#     {
#       "qas": [
#         {
#           "question": "Who asserts that they will respond to direct contacts requesting material be removed from the archive?",
#           "id": "56ddd65866d3e219004dad1b",
#           "answers": [
#             {
#               "text": "Internet Archive",
#               "answer_start": 4
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "Internet Archive",
#               "answer_start": 4
#             }
#           ],
#           "question": "Who asserts that they will respond to direct contracts requesting material be removed from Web sites?",
#           "id": "5a6b295ba9e0c9001a4e9f12",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "preserving or offering access to Web sites or other Internet documents of persons who do not want their materials in the collection",
#               "answer_start": 246
#             }
#           ],
#           "question": "What are owners not interested in?",
#           "id": "5a6b295ba9e0c9001a4e9f13",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "comply",
#               "answer_start": 142
#             }
#           ],
#           "question": "What do Web site owners do with requests?",
#           "id": "5a6b295ba9e0c9001a4e9f14",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "directly",
#               "answer_start": 81
#             }
#           ],
#           "question": "How does the Internet Archives contact owners?",
#           "id": "5a6b295ba9e0c9001a4e9f15",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "Internet Archive",
#               "answer_start": 208
#             }
#           ],
#           "question": "Who is interested in preserving Web sites of persons who do not want their materials in the collection?",
#           "id": "5a6b295ba9e0c9001a4e9f16",
#           "answers": [],
#           "is_impossible": true
#         }
#       ],
#       "context": "The Internet Archive states, however, \"Sometimes a website owner will contact us directly and ask us to stop crawling or archiving a site. We comply with these requests.\" In addition, the web site says: \"The Internet Archive is not interested in preserving or offering access to Web sites or other Internet documents of persons who do not want their materials in the collection.\""
#     },
#     {
#       "qas": [
#         {
#           "question": "Who sued Internet Archive in 2005?",
#           "id": "56ddd8849a695914005b960c",
#           "answers": [
#             {
#               "text": "Suzanne Shell",
#               "answer_start": 27
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "question": "What was the URL owned by Suzanne Shell?",
#           "id": "56ddd8849a695914005b960d",
#           "answers": [
#             {
#               "text": "profane-justice.org",
#               "answer_start": 126
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "question": "In what jurisdiction were Internet Archive's counterclaims filed?",
#           "id": "56ddd8849a695914005b960f",
#           "answers": [
#             {
#               "text": "Northern District of California",
#               "answer_start": 266
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "question": "In what jurisdiction where counterclaims nullified by the court?",
#           "id": "56ddd8849a695914005b9610",
#           "answers": [
#             {
#               "text": "District of Colorado",
#               "answer_start": 634
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "Suzanne Shell",
#               "answer_start": 27
#             }
#           ],
#           "question": "Who sued Internet Archive in 2004?",
#           "id": "5a6b2b06a9e0c9001a4e9f1c",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "profane-justice.org",
#               "answer_start": 126
#             }
#           ],
#           "question": "What was the URL owned by the Internet Archive?",
#           "id": "5a6b2b06a9e0c9001a4e9f1d",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "Northern District of California",
#               "answer_start": 266
#             }
#           ],
#           "question": "In what jurisdiction was Suzanne Shell's counterclaims filed?",
#           "id": "5a6b2b06a9e0c9001a4e9f1e",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "District of Colorado",
#               "answer_start": 634
#             }
#           ],
#           "question": "In what jurisdiction were claims nullified by the court?",
#           "id": "5a6b2b06a9e0c9001a4e9f1f",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "January 20, 2006",
#               "answer_start": 301
#             }
#           ],
#           "question": "When did Suzanne Shell file a declaratory judgment action?",
#           "id": "5a6b2b06a9e0c9001a4e9f20",
#           "answers": [],
#           "is_impossible": true
#         }
#       ],
#       "context": "In December 2005, activist Suzanne Shell filed suit demanding Internet Archive pay her US $100,000 for archiving her web site profane-justice.org between 1999 and 2004. Internet Archive filed a declaratory judgment action in the United States District Court for the Northern District of California on January 20, 2006, seeking a judicial determination that Internet Archive did not violate Shell's copyright. Shell responded and brought a countersuit against Internet Archive for archiving her site, which she alleges is in violation of her terms of service. On February 13, 2007, a judge for the United States District Court for the District of Colorado dismissed all counterclaims except breach of contract. The Internet Archive did not move to dismiss copyright infringement claims Shell asserted arising out of its copying activities, which would also go forward."
#     },
#     {
#       "qas": [
#         {
#           "question": "When did Suzanne Shell's suit against Internet Archive come to an end?",
#           "id": "56ddd98d9a695914005b961a",
#           "answers": [
#             {
#               "text": "April 25, 2007",
#               "answer_start": 3
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "question": "Who stated that they had no wish to violate individuals' copyrights?",
#           "id": "56ddd98d9a695914005b961b",
#           "answers": [
#             {
#               "text": "Internet Archive",
#               "answer_start": 19
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "question": "Who stated that they did not want to cause damage to the Internet Archive?",
#           "id": "56ddd98d9a695914005b961c",
#           "answers": [
#             {
#               "text": "Suzanne Shell",
#               "answer_start": 40
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "April 25, 2007",
#               "answer_start": 3
#             }
#           ],
#           "question": "When did Wayback Machine's suit against Internet Archive come to an end?",
#           "id": "5a6b2d63a9e0c9001a4e9f26",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "Internet Archive",
#               "answer_start": 109
#             }
#           ],
#           "question": "Who stated that they had no wish to violate the values of Suzanne Shell?",
#           "id": "5a6b2d63a9e0c9001a4e9f27",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "Suzanne Shell",
#               "answer_start": 40
#             }
#           ],
#           "question": "Who stated that they did not want to cause damage to the Wayback Machine?",
#           "id": "5a6b2d63a9e0c9001a4e9f28",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "Internet Archive",
#               "answer_start": 109
#             }
#           ],
#           "question": "Who regretted the inclusion of Wayback Mountain's Web site?",
#           "id": "5a6b2d63a9e0c9001a4e9f29",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "Internet Archive",
#               "answer_start": 109
#             }
#           ],
#           "question": "Who never intended to interfere with Suzanne Shell's goal?",
#           "id": "5a6b2d63a9e0c9001a4e9f2a",
#           "answers": [],
#           "is_impossible": true
#         }
#       ],
#       "context": "On April 25, 2007, Internet Archive and Suzanne Shell jointly announced the settlement of their lawsuit. The Internet Archive said it \"...has no interest in including materials in the Wayback Machine of persons who do not wish to have their Web content archived. We recognize that Ms. Shell has a valid and enforceable copyright in her Web site and we regret that the inclusion of her Web site in the Wayback Machine resulted in this litigation.\" Shell said, \"I respect the historical value of Internet Archive's goal. I never intended to interfere with that goal nor cause it any harm.\""
#     },
#     {
#       "qas": [
#         {
#           "question": "What was the first method used by the actor in trying to get his images taken down?",
#           "id": "56ddd9ea66d3e219004dad24",
#           "answers": [
#             {
#               "text": "DMCA requests",
#               "answer_start": 107
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "question": "What legal system did the actor use after filing DMCA petitions?",
#           "id": "56ddd9ea66d3e219004dad25",
#           "answers": [
#             {
#               "text": "Federal Court of Canada",
#               "answer_start": 152
#             }
#           ],
#           "is_impossible": false
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "DMCA requests",
#               "answer_start": 107
#             }
#           ],
#           "question": "What was the first method used by the actor in trying to get the DMCA taken down?",
#           "id": "5a6b2ed4a9e0c9001a4e9f30",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "Federal Court of Canada",
#               "answer_start": 152
#             }
#           ],
#           "question": "What legal actions did the actor use after filing pornographic images?",
#           "id": "5a6b2ed4a9e0c9001a4e9f31",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "2013\u201314",
#               "answer_start": 3
#             }
#           ],
#           "question": "When did a pornographic actor send multiple requests to DMCA?",
#           "id": "5a6b2ed4a9e0c9001a4e9f32",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "archived images",
#               "answer_start": 53
#             }
#           ],
#           "question": "What was the DMCA trying to remove?",
#           "id": "5a6b2ed4a9e0c9001a4e9f33",
#           "answers": [],
#           "is_impossible": true
#         },
#         {
#           "plausible_answers": [
#             {
#               "text": "2013\u201314",
#               "answer_start": 3
#             }
#           ],
#           "question": "When was the DMCA trying to remove archived images?",
#           "id": "5a6b2ed4a9e0c9001a4e9f34",
#           "answers": [],
#           "is_impossible": true
#         }
#       ],
#       "context": "In 2013\u201314 a pornographic actor was trying to remove archived images of himself, first by sending multiple DMCA requests to the Archive and then in the Federal Court of Canada."
#     }
#   ]
# }

# %% [markdown]
# #### KorQuAD vs SQuAD
#
# - KorQuAD
#   1. ROOT : version, data(list)
#   2. data : title, url, context, raw_html, qas
#   3. qas(list) : answer(list), id, question
#   4. answer : answer_start, html_answer_start, html_answer_text, text,
#
# - SQuAD
#   1. ROOT : version, data(list)
#   2. data : title, paragraphs(list)
#   3. paragraphs : context, qas
#   4. qas(list) : answers, id, is_impossible, question
#   5. answers : answer_start, text

# %%
def KorToStanford(dir, output, pattern='*.json', cnt=-1):
    files = glob.glob(dir + pattern)
    version = ''
    datalist = []
    for f in files:
        print(f)
        if cnt == 0:
          break
        json_file = open(f, encoding='utf-8')
        json_data = json.load(json_file)
        version = json_data['version']
        dataz = json_data['data']
        for data in dataz:
            if 'qas' in data.keys():
                paragraphs = {}
                qaslist = data['qas']
                for qas in qaslist:
                    qas['answer'].pop('html_answer_start')  # html_answer_start 삭제
                    qas['answer'].pop('html_answer_text')  # html_answer_text 삭제
                    qas['answers'] = [qas['answer']]  # answer --> answers
                    qas['is_impossible'] = False  # is_impossible 삽입
                    qas.pop('answer')  # answer 삭제
                paragraphs['title'] = data['title']
                paragraphs['paragraphs'] = [{'context': data['context'], 'qas': qaslist}]
                datalist.append(paragraphs)
                cnt -= 1

    changed = {'version': version, 'data': datalist}

    with open(output, 'w') as f:
        json.dump(changed, f)

# %%
KorToStanford('/content/gdrive/My Drive/ai-summit/model/train/', '/content/gdrive/My Drive/ai-summit/new_train.json', cnt=1000)
KorToStanford('/content/gdrive/My Drive/ai-summit/model/dev/', '/content/gdrive/My Drive/ai-summit/new_dev.json', cnt=300)
# Out:
# /content/gdrive/My Drive/ai-summit/model/train/korquad2.1_train_00.json
# /content/gdrive/My Drive/ai-summit/model/train/korquad2.1_train_01.json
# /content/gdrive/My Drive/ai-summit/model/dev/korquad2.1_dev_00.json
# /content/gdrive/My Drive/ai-summit/model/dev/korquad2.1_dev_01.json
# /content/gdrive/My Drive/ai-summit/model/dev/korquad2.1_dev_02.json
# /content/gdrive/My Drive/ai-summit/model/dev/korquad2.1_dev_03.json
# /content/gdrive/My Drive/ai-summit/model/dev/korquad2.1_dev_04.json

# %%
showJson('/content/gdrive/My Drive/ai-summit/new_train.json', 34)
# Out:
# {
#   "title": "\uc778\uc81c\uc74d",
#   "paragraphs": [
#     {
#       "context": "<!DOCTYPE html>\n<html>\n<head>\n<meta>\n<title>\uc778\uc81c\uc74d - \uc704\ud0a4\ubc31\uacfc, \uc6b0\ub9ac \ubaa8\ub450\uc758 \ubc31\uacfc\uc0ac\uc804</title>\n\n\n<link>\n\n<meta>\n<link>\n<meta>\n<meta>\n<meta>\n<meta>\n<meta>\n<link>\n<link>\n<link>\n<link>\n<link>\n<link>\n<link>\n<link>\n<link>\n<link>\n<link>\n\n</head>\n<body>\n<div></div>\n<div></div>\n<div>\n<a></a>\n<div></div>\n<div>\n</div>\n<h1>\uc778\uc81c\uc74d</h1>\n<div>\n<div>\uc704\ud0a4\ubc31\uacfc, \uc6b0\ub9ac \ubaa8\ub450\uc758 \ubc31\uacfc\uc0ac\uc804.</div>\n<div></div>\n<div></div>\n<a>\ub458\ub7ec\ubcf4\uae30\ub85c \uac00\uae30</a>\n<a>\uac80\uc0c9\ud558\ub7ec \uac00\uae30</a>\n<div><div><table>\n<caption><span><a>\uac15\uc6d0\ub3c4</a> <a>\uc778\uc81c\uad70</a></span>\n</caption>\n<tbody><tr>\n<th colspan=\"2\"><span><b>\uc778\uc81c\uc74d</b></span>\n</th></tr>\n<tr>\n<td colspan=\"2\">\u9e9f\u8e44\u9091 Inje-eup\n</td></tr>\n<tr>\n<td colspan=\"2\"><a><img></a>\n</td></tr>\n<tr>\n<th><span>\uba74\uc801 </span>\n</th>\n<td>315.15\u00a0km<sup>2</sup>\n</td></tr>\n<tr>\n<th><span>\uc778\uad6c </span>\n</th>\n<td>9,661\uba85 (<a>2011\ub144</a> <a>12\uc6d4 31\uc77c</a>)\n</td></tr>\n<tr>\n<th>\uc778\uad6c\ubc00\ub3c4\n</th>\n<td>31 \uba85/km<sup>2</sup>\n</td></tr>\n<tr>\n<th><span>\uc138\ub300 </span>\n</th>\n<td>3,927\uac00\uad6c (<a>2011\ub144</a> <a>12\uc6d4 31\uc77c</a>)\n</td></tr>\n<tr>\n<th><span><a>\ubc95\uc815\ub9ac</a> </span>\n</th>\n<td>11\n</td></tr>\n<tr>\n<th><span><a>\ud589\uc815\ub9ac</a> </span>\n</th>\n<td>20\n</td></tr>\n<tr>\n<th><span>\ubc18 </span>\n</th>\n<td>119\n</td></tr>\n<tr>\n<th><span>\uba74\uc0ac\ubb34\uc18c </span>\n</th>\n<td>\uc778\uc81c\uc74d \uc778\uc81c\ub85c 205\ubc88\uae38 9\n</td></tr>\n<tr>\n<th><span>\ud648\ud398\uc774\uc9c0 </span>\n</th>\n<td><a>\uc778\uc81c\uc74d\uc0ac\ubb34\uc18c</a>\n</td></tr>\n</tbody></table>\n<p><b>\uc778\uc81c\uc74d</b>(\u9e9f\u8e44\u9091)\uc740 <a>\ub300\ud55c\ubbfc\uad6d</a> <a>\uac15\uc6d0\ub3c4</a> <a>\uc778\uc81c\uad70</a>\uc758 <a>\ud589\uc815</a>, <a>\uad50\ud1b5</a>, <a>\uc0b0\uc5c5</a>\uc758 \uc911\uc2ec\uc9c0\uc774\ub2e4.\n</p>\n<div><input><div><h2>\ubaa9\ucc28</h2><span><label></label></span></div>\n<ul>\n<li><a><span>1</span> <span>\uac1c\uc694</span></a></li>\n<li><a><span>2</span> <span>\uc5f0\ud601</span></a></li>\n<li><a><span>3</span> <span>\ud589\uc815 \uad6c\uc5ed</span></a></li>\n<li><a><span>4</span> <span>\uac01\uc8fc</span></a></li>\n<li><a><span>5</span> <span>\uc678\ubd80 \ub9c1\ud06c</span></a></li>\n</ul>\n</div>\n<h2><span></span><span>\uac1c\uc694</span><span><span>[</span><a>\ud3b8\uc9d1</a><span>]</span></span></h2>\n<p><a>\uc18c\uc591\uac15</a>\uacfc <a>\ub0b4\ub9b0\ucc9c</a>\uc758 \ud569\ub958\uc810 \uac00\uae4c\uc774\uc5d0 \uc788\uace0 \ubd80\uadfc \uc77c\ub300\ub294 \uacbd\uce58\uac00 \uc544\ub984\ub2f5\ub2e4. \ub300\ud55c\ubbfc\uad6d \uc81c\uc77c\uc758 \ubc00\uc6d0\uc9c0\ub85c <a>\uafc0</a>\uc758 \uc0dd\uc0b0\ub7c9\uc774 \ub9ce\uace0 \uc784\uc0b0\ubb3c\uc758 \uc0dd\uc0b0\ub7c9\ub3c4 \ub9ce\ub2e4. <a>\uae08\uac15\uc0b0</a>\uc5d0 \ubabb\uc9c0 \uc54a\ub294 \ub0b4\uc124\uc545 \uc77c\ub300\uc758 <a>\uae30\uc554 \uad34\uc11d</a>, \ube44\ud3ed, \ubcbd\ub2f4, \uc0bc\ub9bc\ubbf8 \ub4f1\uc758 \uacbd\uc2b9\uc9c0\uac00 \ub9ce\uc544 <a>\uad00\uad11</a><a>\uc0ac\uc5c5</a>\uc774 \uc720\ub9dd\ud55c \uacf3\uc774\ub2e4.\n</p><p>\ub3d9\ucabd\uc73c\ub85c\ub294 <a>\uc591\uc591\uad70</a> <a>\uc11c\uba74</a>, \uc11c\ucabd\uc740 \ub0a8\uba74(\u5357\u9762), \ub0a8\ucabd\uc740 <a>\uae30\ub9b0\uba74</a>\uc5d0, \ubd81\ucabd\uc740 <a>\ubd81\uba74</a>\uc5d0 \ub2ff\uc544 \uc788\ub2e4. \uc0c1\ub3d9\ub9ac\uc5d0 \uc778\uc81c\uad70\uccad\uc774 \uc788\uace0, \uc74d\uc0ac\ubb34\uc18c \uc9c1\ud560 \uadc0\ub454\ucd9c\uc7a5\uc18c\uac00 \uc124\uce58\ub418\uc5b4 \uc788\ub2e4.\n</p>\n<h2><span></span><span>\uc5f0\ud601</span><span><span>[</span><a>\ud3b8\uc9d1</a><span>]</span></span></h2>\n<ul><li>\ubcf8\ub798 \ud604\ub0b4\uba74(\u7e23\u5167\u9762)\uc774\ub77c\uace0 \ud ...
#       "qas": [
#         {
#           "question": "\uc778\uc81c\uc74d\uc758 \ubc95\uc815\ub9ac \uac00\uc544\ub9ac\ub294 \uc5b4\ub5a4 \ud589\uc815\ub9ac\ub85c \ubd84\ub9ac\ub418\ub294\uac00?",
#           "id": "21847",
#           "answers": [
#             {
#               "text": "<td>\uac00\uc5441\ub9ac, \uac00\uc5442\ub9ac</td>",
#               "answer_start": 3101
#             }
#           ],
#           "is_impossible": false
#         }
#       ]
#     }
#   ]
# }

# %%
showJson('/content/gdrive/My Drive/ai-summit/new_dev.json', 20)
# Out:
# {
#   "title": "\uae40\uc0c1\ud6c8_(1963\ub144)",
#   "paragraphs": [
#     {
#       "context": "<!DOCTYPE html>\n<html>\n<head>\n<meta>\n<title>\uae40\uc0c1\ud6c8 (1963\ub144) - \uc704\ud0a4\ubc31\uacfc, \uc6b0\ub9ac \ubaa8\ub450\uc758 \ubc31\uacfc\uc0ac\uc804</title>\n\n\n<link>\n\n<meta>\n<link>\n<meta>\n<meta>\n<meta>\n<meta>\n<link>\n<link>\n<link>\n<link>\n<link>\n<link>\n<link>\n<link>\n<link>\n<link>\n<link>\n\n</head>\n<body>\n<div></div>\n<div></div>\n<div>\n<a></a>\n<div></div>\n<div>\n</div>\n<h1>\uae40\uc0c1\ud6c8 (1963\ub144)</h1>\n<div>\n<div>\uc704\ud0a4\ubc31\uacfc, \uc6b0\ub9ac \ubaa8\ub450\uc758 \ubc31\uacfc\uc0ac\uc804.</div>\n<div></div>\n<div></div>\n<a>\ub458\ub7ec\ubcf4\uae30\ub85c \uac00\uae30</a>\n<a>\uac80\uc0c9\ud558\ub7ec \uac00\uae30</a>\n<div><div><table><tbody><tr><th colspan=\"2\"><div><div></div><span>\uae40\uc0c1\ud6c8</span></div></th></tr><tr><th colspan=\"2\">\uae30\ubcf8 \uc815\ubcf4</th></tr><tr><th>\uad6d\uc801</th>\n<td>\n\ub300\ud55c\ubbfc\uad6d</td></tr><tr><th>\ucd9c\uc0dd</th>\n<td>\n1963\ub144 1\uc6d4 25\uc77c<span>(<span>1963-01-25</span>)</span> (56\uc138)<br/>\ub300\ud55c\ubbfc\uad6d <a>\uacbd\uc0c1\ubd81\ub3c4</a> <a>\ub300\uad6c\uc2dc</a> <a>\uc11c\uad6c</a> <a>\ube44\uc0b0\ub3d9</a></td></tr><tr><th>\uac70\uc8fc\uc9c0</th>\n<td>\n\ub300\ud55c\ubbfc\uad6d <a>\ub300\uad6c\uad11\uc5ed\uc2dc</a> <a>\uc11c\uad6c</a></td></tr><tr><th>\ud559\ub825</th>\n<td>\n<a>\uc601\ub0a8\ub300\ud559\uad50</a> \ubc95\ud559 \ud559\uc0ac<br/><a>\uc624\ub9ac\uac74 \ub300\ud559\uad50</a> \ud589\uc815\ub300\ud559\uc6d0 \ud589\uc815\ud559 \uc11d\uc0ac</td></tr>\n<tr><th>\uad70\ubcf5\ubb34</th>\n<td>\n\uc721\uad70\ubcd1\uc7a5 \ub9cc\uae30\uc81c\ub300</td></tr><tr><th>\uc885\uad50</th>\n<td>\n<a>\ucc9c\uc8fc\uad50</a>(\uc138\ub840\uba85: \ubca0\ub4dc\ub85c)</td></tr><tr><th>\uc758\uc6d0 \uc120\uc218</th>\n<td>\n2</td></tr><tr><th>\uc758\uc6d0 \ub300\uc218</th>\n<td>\n19\u00b720</td></tr><tr><th>\uc815\ub2f9</th>\n<td>\n<a>\uc790\uc720\ud55c\uad6d\ub2f9</a></td></tr><tr><th>\uc9c0\uc5ed\uad6c</th>\n<td>\n<a>\ub300\uad6c \uc11c\uad6c</a></td></tr><tr><th>\ub2f9\ub0b4 \uc9c1\ucc45</th>\n<td>\n\uc815\ucc45\uc704\uc6d0\ud68c \ubd80\uc758\uc7a5</td></tr><tr><th>\uc6f9\uc0ac\uc774\ud2b8</th>\n<td>\n<a>http://kimsh.or.kr/ps/</a></td></tr>\n</tbody></table>\n<p><b>\uae40\uc0c1\ud6c8</b>(\u91d1\u76f8\u52f3, <a>1963\ub144</a> <a>1\uc6d4 25\uc77c</a> <a>\ub300\uad6c</a> ~ )\uc740 <a>\ub300\ud55c\ubbfc\uad6d</a> \uc804 \uacf5\ubb34\uc6d0\uc774\uc790 \uc815\uce58\uc778\uc774\ub2e4.\n</p>\n<div><input><div><h2>\ubaa9\ucc28</h2><span><label></label></span></div>\n<ul>\n<li><a><span>1</span> <span>\uc57d\ub825</span></a></li>\n<li><a><span>2</span> <span>\uacbd\ub825</span></a></li>\n<li><a><span>3</span> <span>\uc758\uc815 \ud65c\ub3d9</span></a></li>\n<li><a><span>4</span> <span>\ud45c\ucc3d</span></a></li>\n<li><a><span>5</span> <span>\uc800\uc11c</span></a></li>\n<li><a><span>6</span> <span>\ubcd1\uc5ed\uc0ac\ud56d</span></a></li>\n<li><a><span>7</span> <span>\uc5ed\ub300 \uc120\uac70 \uacb0\uacfc</span></a></li>\n</ul>\n</div>\n<h2><span></span><span>\uc57d\ub825</span><span><span>[</span><a>\ud3b8\uc9d1</a><span>]</span></span></h2>\n<ul><li>1963.01.25: <a>\ub300\uad6c\uc2dc</a> <a>\ube44\uc0b0\ub3d9</a> \ucd9c\uc0dd</li>\n<li>1969.03 ~ 1975.02: <a>\ub300\uad6c\uc11c\ubd80\ucd08\ub4f1\ud559\uad50</a>(56\ud68c)</li>\n<li>1975.03 ~ 1978.02: <a>\uc131\uad11\uc911\ud559\uad50</a></li>\n<li>1978.03 ~ 1981.02: <a>\ub300\uad6c\ub300\uac74\uace0\ub4f1\ud559\uad50</a></li>\n<li>1989\ub144: \ud589\uc815\uace0\uc2dc \ud569\uaca9(\uc81c33\ud68c)</li>\n<li>1990\ub144: <a>\uc601\ub0a8\ub300\ud559\uad50</a> \ubc95\ud559\uacfc \uc878\uc5c5</li>\n<li>1994\ub144: <a>\uc11c\uc6b8\ub300\ud559\uad50</a> \ud589\uc815\ub300\ud559\uc6d0 1\ub144 \uc911\ud1f4[1\ud559\uae30 \uc218\ud559]</li>\n<li>2004\ub144 8\uc6d4 ~ 2006\ub144 6\uc6d4: \ubbf8\uad6d \uc624\ub9ac\uac74 \ub300\ud559\uad50 \ub300\ud559\uc6d0 \ud589\uc815\ud559 \uc11d\uc0ac</li></ul>\n<h2><span></span><span>\uacbd\ub825</span><span><span>[</span><a>\ud3b ...
#       "qas": [
#         {
#           "question": "\uae40\uc0c1\ud6c8\uc774 \uc81c33\ud68c \ud589\uc815\uace0\uc2dc\uc5d0 \ud569\uaca9\ud55c \uc5f0\ub3c4\ub294 \uc5b8\uc81c\uc77c\uae4c?",
#           "id": "37433",
#           "answers": {
#             "text": "1989\ub144",
#             "answer_start": 2013
#           },
#           "is_impossible": false
#         }
#       ]
#     }
#   ]
# }

# %% [markdown]
# ### Training

# %%
# !python /content/gdrive/My\ Drive/ai-summit/run_squad.py \
--vocab_file=/content/gdrive/My\ Drive/ai-summit/model/multi_cased_L-12_H-768_A-12/vocab.txt \
--bert_config_file=/content/gdrive/My\ Drive/ai-summit/model/multi_cased_L-12_H-768_A-12/bert_config.json \
--init_checkpoint=/content/gdrive/My\ Drive/ai-summit/model/multi_cased_L-12_H-768_A-12/bert_model.ckpt \
--do_train=True \
--train_file=/content/gdrive/My\ Drive/ai-summit/new_train.json \
--do_predict=True \
--predict_file=/content/gdrive/My\ Drive/ai-summit/new_dev.json \
--train_batch_size=16 \
--learning_rate=3e-5 \
--num_train_epochs=2.0 \
--max_seq_length=256 \
--doc_stride=128 \
--output_dir=/content/gdrive/My\ Drive/ai-summit/tmp \
--do_lower_case=False
# Out:
# Output hidden; open in https://colab.research.google.com to view.
